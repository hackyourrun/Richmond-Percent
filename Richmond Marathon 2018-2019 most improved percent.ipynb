# %% [markdown]
# # Richmond Marathon Anaysis: Most Improvement from 2018-2019 in Percent
#
# This Notebook takes information posted by the Richmond Marathon, creates a .csv file for each of them, creates data frames from each, and adds columns for race year. Then the data frames are merged based on names appearing in both years race results, filters for results where the age difference is not plausibly the same runner, then sorts by most imporoved percentage of time. This process will only recognize times as belonging to the same runner when the race recorded the same name.
#
# To run this notebook, use Cell- Run All. The output will be a .csv file named Richmond_Improved_Percent.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('RichmondMarathon2018.csv')  #imports .csv's to data frames
df2 = pd.read_csv('RichmondMarathon2019D.csv')

# %%
df1 = df1.rename(columns = lambda x: x.strip()) #removes spaces from column names so they can be merged
df2 = df2.rename(columns = lambda x: x.strip())
df1['Name'] = df1['Name'].str.strip() #erases spaces
df2['Name'] = df2['Name'].str.strip()
df1['Age'] = df1['Age'].astype(str).str.strip().astype('int64') #erases spaces, changes to int
df2['Age'] = df2['Age'].astype(str).str.strip().astype('int64', errors='ignore')
df1['Net'] = pd.to_timedelta(df1['Net']) #changes type to time
df2['Net'] = pd.to_timedelta(df2['Net'])

# %%
df1['Race_Year'] = 2018 #adds a column for race year
df2['Race_Year'] = 2019
df1['Net_In_Hours'] = df1['Net'] / np.timedelta64(1,'h') #adds a column for hours, to make it easier to plot 
df2['Net_In_Hours'] = df2['Net'] / np.timedelta64(1,'h')

# %%
merged_inner = pd.merge(left=df1, right=df2, left_on='Name', right_on='Name') #merges the data frames based on runner name
merged_inner['Age_Difference'] = ((merged_inner['Age_y'].astype('int32')) - (merged_inner['Age_x'].astype('int32')))
print(len(merged_inner)) #number of runners both year with the same name 
merged_inner = merged_inner[merged_inner.Age_Difference >= 0] #filters runners with the same name but aged backwords 
merged_inner = merged_inner[merged_inner.Age_Difference < 3] #filters runners with the same nave and age difference more than 3
print(len(merged_inner)) #number of runners after filters
# Out:
# 728
# 709

# %%
merged_inner['Compare_Years']=pd.Series(merged_inner['Net_y']-merged_inner['Net_x']) #makes a column for differnce in race time
most_improved = merged_inner[merged_inner.Age_Difference <3].sort_values('Compare_Years') #sorts field by change in race time
display(most_improved)
# Out:
#      Bib_x                     Name Sex_x  Age_x       City, State_x    Net_x  \
# 419    935           KEVAUGHN SMITH     M     41          NEWARK, NJ 06:03:06
# 18    8517                 ALLEN MA     M     49      GLEN ALLEN, VA 04:57:31
# 610   2000              SAMUEL LIAN     M     25         HENRICO, VA 05:54:02
# 559   4630             PATRICK BOYD     M     52  VIRGINIA BEACH, VA 06:23:20
# 702   7302          VICTORIA HEBERT     F     24       LYNCHBURG, VA 06:34:33
# ..     ...                      ...   ...    ...                 ...      ...
# 462   2049              LISA CURTIN     F     38         MOSELEY, VA 03:47:12
# 648   5357  SIVASUBRAMANIAN SIVARAJ     M     35       CHANTILLY, VA 04:34:58
# 428   4747             KIM ENGLEMAN     F     46        RICHMOND, VA 04:52:40
# 173   6660              DAWN WALKER     F     47        RICHMOND, VA 04:50:20
# 196   1499              DYLAN GIBBS     M     19        RICHMOND, VA 03:32:25
#
#       Clock_x       Pace  Race_Year_x  Net_In_Hours_x  Bib_y Sex_y Age_y  \
# 419  06:06:13  13:50 /mi         2018        6.051667   6172     M    42
# 18   04:59:07  11:20 /mi         2018        4.958611   3152     M    50
# 610  05:55:11  13:30 /mi         2018        5.900556   5880     M    26
# 559  06:30:18  14:37 /mi         2018        6.388889    912     M    53
# 702  06:44:55  15:02 /mi         2018        6.575833   5425     F    25
# ..        ...        ...          ...             ...    ...   ...   ...
# 462  03:48:56   8:39 /mi         2018        3.786667   4382     F    39
# 648  04:36:55  10:29 /mi         2018        4.582778   1006     M    36
# 428  04:59:22  11:09 /mi         2018        4.877778   2855     F    47
# 173  04:57:16  11:04 /mi         2018        4.838889   2856     F    48
# 196  03:33:03   8:06 /mi         2018        3.540278    968     M    20
#
#           City, State_y    Net_y   Clock_y  Race_Year_y  Net_In_Hours_y  \
# 419          NEWARK, NJ 04:15:08  04:16:48         2019        4.252222
# 18       GLEN ALLEN, VA 03:27:27  03:30:34         2019        3.457500
# 610         HENRICO, VA 04:29:03  04:33:47         2019        4.484167
# 559  VIRGINIA BEACH, VA 05:00:20  05:04:31         2019        5.005556
# 702       LYNCHBURG, VA 05:17:21  05:19:27         2019        5.289167
# ..                  ...      ...       ...          ...             ...
# 462    REISTERSTOWN, MD 05:22:27  05:27:53         2019        5.374167
# 648       CHANTILLY, VA 06:27:41  06:29:54         2019        6.461389
# 428        RICHMOND, VA 06:45:59  06:54:03         2019        6.766389
# 173        RICHMOND, VA 07:17:50  07:24:50         2019        7.297222
# 196        RICHMOND, VA 06:57:27  07:08:57         2019        6.957500
#
#      Age_Difference     Compare_Years
# 419               1 -1 days +22:12:02
# 18                1 -1 days +22:29:56
# 610               1 -1 days +22:35:01
# 559               1 -1 days +22:37:00
# 702               1 -1 days +22:42:48
# ..              ...               ...
# 462               1          01:35:15
# 648               1          01:52:43
# 428               1          01:53:19
# 173               1          02:27:30
# 196               1          03:25:02
#
# [709 rows x 20 columns]

# %%
merged_inner['percent_change']=(((merged_inner['Net_x']-merged_inner['Net_y'])/merged_inner['Net_x'])*100) #makes a column for a percentage change in race time
most_improved_perc = merged_inner[merged_inner.Age_Difference <3].sort_values('percent_change', ascending=False) #sorts field by percentage change
display(most_improved_perc)
# Out:
#      Bib_x                     Name Sex_x  Age_x   City, State_x    Net_x  \
# 18    8517                 ALLEN MA     M     49  GLEN ALLEN, VA 04:57:31
# 419    935           KEVAUGHN SMITH     M     41      NEWARK, NJ 06:03:06
# 473   9355           MANGGON COMSAN     M     35     HERNDON, VA 04:38:49
# 610   2000              SAMUEL LIAN     M     25     HENRICO, VA 05:54:02
# 716    895               WILL HYMES     M     28    RICHMOND, VA 04:05:14
# ..     ...                      ...   ...    ...             ...      ...
# 428   4747             KIM ENGLEMAN     F     46    RICHMOND, VA 04:52:40
# 648   5357  SIVASUBRAMANIAN SIVARAJ     M     35   CHANTILLY, VA 04:34:58
# 462   2049              LISA CURTIN     F     38     MOSELEY, VA 03:47:12
# 173   6660              DAWN WALKER     F     47    RICHMOND, VA 04:50:20
# 196   1499              DYLAN GIBBS     M     19    RICHMOND, VA 03:32:25
#
#       Clock_x       Pace  Race_Year_x  Net_In_Hours_x  ...  Sex_y Age_y  \
# 18   04:59:07  11:20 /mi         2018        4.958611  ...      M    50
# 419  06:06:13  13:50 /mi         2018        6.051667  ...      M    42
# 473  04:39:03  10:38 /mi         2018        4.646944  ...      M    36
# 610  05:55:11  13:30 /mi         2018        5.900556  ...      M    26
# 716  04:06:50   9:21 /mi         2018        4.087222  ...      M    29
# ..        ...        ...          ...             ...  ...    ...   ...
# 428  04:59:22  11:09 /mi         2018        4.877778  ...      F    47
# 648  04:36:55  10:29 /mi         2018        4.582778  ...      M    36
# 462  03:48:56   8:39 /mi         2018        3.786667  ...      F    39
# 173  04:57:16  11:04 /mi         2018        4.838889  ...      F    48
# 196  03:33:03   8:06 /mi         2018        3.540278  ...      M    20
#
#         City, State_y    Net_y   Clock_y Race_Year_y  Net_In_Hours_y  \
# 18     GLEN ALLEN, VA 03:27:27  03:30:34        2019        3.457500
# 419        NEWARK, NJ 04:15:08  04:16:48        2019        4.252222
# 473       HERNDON, VA 03:22:14  03:22:39        2019        3.370556
# 610       HENRICO, VA 04:29:03  04:33:47        2019        4.484167
# 716      RICHMOND, VA 03:07:23  03:07:36        2019        3.123056
# ..                ...      ...       ...         ...             ...
# 428      RICHMOND, VA 06:45:59  06:54:03        2019        6.766389
# 648     CHANTILLY, VA 06:27:41  06:29:54        2019        6.461389
# 462  REISTERSTOWN, MD 05:22:27  05:27:53        2019        5.374167
# 173      RICHMOND, VA 07:17:50  07:24:50        2019        7.297222
# 196      RICHMOND, VA 06:57:27  07:08:57        2019        6.957500
#
#      Age_Difference     Compare_Years percent_change
# 18                1 -1 days +22:29:56      30.272814
# 419               1 -1 days +22:12:02      29.734692
# 473               1 -1 days +22:43:25      27.467272
# 610               1 -1 days +22:35:01      24.004331
# 716               1 -1 days +23:02:09      23.589778
# ..              ...               ...            ...
# 428               1          01:53:19     -38.718679
# 648               1          01:52:43     -40.992848
# 462               1          01:35:15     -41.923415
# 173               1          02:27:30     -50.803674
# 196               1          03:25:02     -96.524127
#
# [709 rows x 21 columns]

# %%
most_improved_perc.plot(x='Net_In_Hours_x', y='percent_change', style='o', legend=None, figsize=(20,10)) # plots 2018 time on x axis and percent change on y axis

# %%
most_improved_perc.to_csv('Richmond_Improved_Percent.csv')  # outputs .csv version

# %%
from IPython.display import FileLink
FileLink('./Richmond_Improved_Percent.csv', result_html_prefix="Click here to download: ")
